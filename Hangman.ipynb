# %%
import random 

name = input("What is your name? ")

print("The theme is World Cities! Fighting!", name)
print("TIP : Turn on your caps lock please!")

words = ['PUNE', 'SEOUL', 'NEW YORK', 'TOKYO', 'NEW DELHI', 'MUMBAI', 'PARIS', 'ROME', 'LONDON', 'DUBAI', 'HONG KONG', 
        'SHAINGHAI', 'MOSCOW', 'LOS ANGLES', 'MADRID', 'CHICAGO', 'TORONTO', 'SAN FRANCISCO', 'AMERSTERDAM', 'BERLIN',
        'LAS VEGAS', 'SYDNEY', 'SINGAPORE']

word = random.choice(words) #choose words randomly

print("Guess the characters")

guesses = ''

# any number of turns can be used here
turns = 23


while turns > 0:

    # counts the number of times a user fails
    failed = 0

    # all characters from the input
    # word taking one at a time.
    
    for char in word:
        # comparing that character with
        # the character in guesses
        
        if char in guesses:
            print(char)
        else:
            print("_")
            # for every failure 1 will be
            # incremented in failure
            failed += 1
            
    if failed == 0:
        # user will win the game if failure is 0
        # and 'You Win' will be given as output
        print("You Win")
        # this print the correct word
        print("The word is: ", word)
        break
        
    # if user has input the wrong alphabet then
    # it will ask user to enter another alphabet
    guess = input("Guess a character:")
    # every input character will be stored in guesses
    guesses += guess
    # check input with the character in word
    
    if guess not in word:
        turns -= 1
        # if the character doesn’t match the word
        # then “Wrong” will be given as output
        print("Wrong")
        
        if turns == 0:
            print("You Loose")
# Out:
# What is your name? Nimi
# The theme is World Cities! Fighting! Nimi
# TIP : Turn on your caps lock please!
# Guess the characters
# _
# _
# _
# _
# _
# _
# Guess a character:D
# _
# _
# _
# D
# _
# _
# Guess a character:M
# Wrong
# _
# _
# _
# D
# _
# _
# Guess a character:A
# Wrong
# _
# _
# _
# D
# _
# _
# Guess a character:N
# _
# _
# N
# D
# _
# N
# Guess a character:L
# L
# _
# N
# D
# _
# N
# Guess a character:O
# L
# O
# N
# D
# O
# N
# You Win
# The word is:  LONDON
